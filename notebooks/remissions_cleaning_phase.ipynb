# %%
import pandas as pd

# %%
remissions_df = pd.read_csv("../data/processed/remissions_db.csv")
remissions_df.head(-1)
# Out:
#         Year  tkt_code           order_date  order_code           start_time  \
# 0       2020  51013232  2020-02-04 00:00:00        1073  2020-02-04 07:00:00
# 1       2020  51013233  2020-02-04 00:00:00        1073  2020-02-04 07:00:00
# 2       2020  51013235  2020-02-04 00:00:00        1028  2020-02-04 08:00:00
# 3       2020  51013236  2020-02-04 00:00:00        1005  2020-02-04 08:15:00
# 4       2020  51013238  2020-02-04 00:00:00        1026  2020-02-04 08:30:00
# ...      ...       ...                  ...         ...                  ...
# 340768  2026  71037451  2026-01-31 00:00:00        1069  2026-01-31 11:00:00
# 340769  2026  71037452  2026-01-31 00:00:00        1073  2026-01-31 10:00:00
# 340770  2026  71037453  2026-01-31 00:00:00        1244  2026-01-31 10:00:00
# 340771  2026  71037454  2026-01-31 00:00:00        1070  2026-01-31 12:00:00
# 340772  2026  71037455  2026-01-31 00:00:00        1188  2026-01-31 12:45:00
#
#         truck_code  ship_plant_code  u_Volumen           typed_time  \
# 0             7044              510        6.0  2020-02-04 06:45:13
# 1             6603              510        5.5  2020-02-04 06:45:22
# 2             9631              510        2.5  2020-02-04 07:37:56
# 3             6598              510        3.0  2020-02-04 08:02:36
# 4            10145              510        3.5  2020-02-04 08:09:01
# ...            ...              ...        ...                  ...
# 340768       13053              710        2.0  2026-01-31 10:06:20
# 340769       12831              710        3.0  2026-01-31 10:36:44
# 340770       12831              710        0.5  2026-01-31 10:51:48
# 340771       13041              710        2.5  2026-01-31 10:55:54
# 340772       12829              710        4.5  2026-01-31 12:07:07
#
#               at_plant_time  u_Cicle                                 name  \
# 0       2020-02-04 08:17:24       92                ONE TIME OCTAVIO RIOS
# 1       2020-02-04 08:26:06      101                ONE TIME OCTAVIO RIOS
# 2       2020-02-04 08:55:49       78   ONE TIME ESP ANGELICA RIVERA GOMEZ
# 3       2020-02-04 09:47:43      105             IVAN NOE SIMENTAL ORTEGA
# 4       2020-02-04 09:09:15       60          ONE TIME CONSTRUCENTRO CHIH
# ...                     ...      ...                                  ...
# 340768  2026-01-31 11:03:20       57                  BENJAMIN MATA CONDE
# 340769  2026-01-31 10:50:38       14       FERRETERIA MOLINA DE CHIHUAHUA
# 340770  2026-01-31 13:01:36      130       FERRETERIA MOLINA DE CHIHUAHUA
# 340771  2026-01-31 12:52:16      117              ALFONSO ORTEGA ANTILLON
# 340772  2026-01-31 12:52:23       45  PROMOTORES MEXICANOS DE LA EDUCACIO
#
#                         Nombre del proyecto  \
# 0                        ARMENDARIZ ARMANDO
# 1                        ARMENDARIZ ARMANDO
# 2                              ROMERO JULIA
# 3                       COLECTOR SACRAMENTO
# 4                   MOLINA BALDERRAMA CESAR
# ...                                     ...
# 340768                 VILLAS LA HACIENDITA
# 340769       FERRETERIA MOLINA DE CHIHUAHUA
# 340770       FERRETERIA MOLINA DE CHIHUAHUA
# 340771             FRAC ALCAZARES (MYKONOS)
# 340772  PROMOTORES MEXICANOS DE LA EDUCACIO
#
#                                   ship_addr_line map_page
# 0       HACIENDAS HENEKENERAS 2679 GRACC HACIEND    CH-F1
# 1       HACIENDAS HENEKENERAS 2679 GRACC HACIEND    CH-F1
# 2        CALLE MANUEL BECERRA 14515 COL ALAMEDAS    CH-F5
# 3           ARROLLO MIMBRE Y VIALIDAD SACRAMENTO    CH-J9
# 4       PERIF DE LA JUVENTUD 9926 COL RESIDENCIA    CH-L5
# ...                                          ...      ...
# 340768     EJIDO LA HACIENDITA  S/N    CHIHUAHUA    CHP-4
# 340769           FRACC DOMINIO LOTE 2 MANZANA 10    CHN-3
# 340770           FRACC DOMINIO LOTE 2 MANZANA 10    CHN-3
# 340771  AVE DE LA CANTERA  SN   ALCAZARES (MYKON    CHP-3
# 340772  AV CANTERA S/N COLEGIO REGIONAL DEL NORT    CHP-1
#
# [340773 rows x 15 columns]

# %%
# Based on EDA analysis, it´s okay to drop rows with null values (<2%)
remissions_df = remissions_df[remissions_df['ship_addr_line'].notnull() & remissions_df['map_page'].notnull() & remissions_df['name'].notnull()]
print("Number of rows after dropping null values:", remissions_df.shape[0])
# Out:
# Number of rows after dropping null values: 340244

# %%
# Change 'order_date' and 'typed_time' to datetime format
remissions_df['order_date'] = pd.to_datetime(remissions_df['order_date'], errors='raise', format='mixed')
remissions_df['typed_time'] = pd.to_datetime(remissions_df['typed_time'], errors='raise', format='mixed')
remissions_df['start_time'] = pd.to_datetime(remissions_df['start_time'], errors='raise', format='mixed')
remissions_df['at_plant_time'] = pd.to_datetime(remissions_df['at_plant_time'], errors='raise', format='mixed')
remissions_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 340244 entries, 0 to 340773
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Year                 340244 non-null  int64
#  1   tkt_code             340244 non-null  int64
#  2   order_date           340244 non-null  datetime64[us]
#  3   order_code           340244 non-null  int64
#  4   start_time           340244 non-null  datetime64[us]
#  5   truck_code           340244 non-null  int64
#  6   ship_plant_code      340244 non-null  int64
#  7   u_Volumen            340244 non-null  float64
#  8   typed_time           340244 non-null  datetime64[us]
#  9   at_plant_time        340244 non-null  datetime64[us]
#  10  u_Cicle              340244 non-null  int64
#  11  name                 340244 non-null  str
#  12  Nombre del proyecto  340244 non-null  str
#  13  ship_addr_line       340244 non-null  str
#  14  map_page             340244 non-null  str
# dtypes: datetime64[us](4), float64(1), int64(6), str(4)
# memory usage: 71.3 MB

# %%
typed_time_duplicates = remissions_df[remissions_df.duplicated(subset=['start_time', 'at_plant_time','truck_code'], keep=False)]
typed_time_duplicates = typed_time_duplicates.sort_values(by='typed_time', ascending=True)
typed_time_duplicates.head(10)
# Out:
#        Year  tkt_code order_date  order_code          start_time  truck_code  \
# 77566  2021  51038180 2021-08-12        1155 2021-08-12 10:00:00        6163
# 77567  2021  51038180 2021-08-30        1243 2021-08-12 10:00:00        6163
# 77575  2021  51038191 2021-08-12        1155 2021-08-12 10:00:00        9430
# 77576  2021  51038191 2021-08-30        1243 2021-08-12 10:00:00        9430
# 77579  2021  51038194 2021-08-12        1155 2021-08-12 10:00:00        9431
# 77580  2021  51038194 2021-08-30        1243 2021-08-12 10:00:00        9431
# 77582  2021  51038199 2021-08-12        1155 2021-08-12 10:00:00       10145
# 77583  2021  51038199 2021-08-30        1243 2021-08-12 10:00:00       10145
# 77743  2021  51038418 2021-08-17        1074 2021-08-17 07:30:00       10157
# 77744  2021  51038418 2021-08-20        1336 2021-08-17 07:30:00       10157
#
#        ship_plant_code  u_Volumen          typed_time       at_plant_time  \
# 77566              510        5.0 2021-08-12 10:22:43 2021-08-12 11:54:06
# 77567              510        5.0 2021-08-12 10:22:43 2021-08-12 11:54:06
# 77575              510        5.0 2021-08-12 11:39:18 2021-08-12 12:32:11
# 77576              510        5.0 2021-08-12 11:39:18 2021-08-12 12:32:11
# 77579              510        5.5 2021-08-12 12:00:53 2021-08-12 13:22:00
# 77580              510        5.5 2021-08-12 12:00:53 2021-08-12 13:22:00
# 77582              510        5.5 2021-08-12 12:20:39 2021-08-12 14:02:20
# 77583              510        5.5 2021-08-12 12:20:39 2021-08-12 14:02:20
# 77743              510        6.5 2021-08-17 07:17:00 2021-08-17 08:27:28
# 77744              510        6.5 2021-08-17 07:17:00 2021-08-17 08:27:28
#
#        u_Cicle                        name  Nombre del proyecto  \
# 77566       92  PLANEACION INMOBILIARIA DE    QUORUM  COMERCIAL
# 77567       92  PLANEACION INMOBILIARIA DE    QUORUM  COMERCIAL
# 77575       53  PLANEACION INMOBILIARIA DE    QUORUM  COMERCIAL
# 77576       53  PLANEACION INMOBILIARIA DE    QUORUM  COMERCIAL
# 77579       82  PLANEACION INMOBILIARIA DE    QUORUM  COMERCIAL
# 77580       82  PLANEACION INMOBILIARIA DE    QUORUM  COMERCIAL
# 77582      102  PLANEACION INMOBILIARIA DE    QUORUM  COMERCIAL
# 77583      102  PLANEACION INMOBILIARIA DE    QUORUM  COMERCIAL
# 77743       70  MATERIALES INDUSTRIALES DE  SANTA CLARA PONENTE
# 77744       70  MATERIALES INDUSTRIALES DE  SANTA CLARA PONENTE
#
#                                  ship_addr_line map_page
# 77566  CITADELA SECTOR 49 FRACC 63 QUORUM  COME    CH-N1
# 77567  CITADELA SECTOR 49 FRACC 63 QUORUM  COME    CH-N1
# 77575  CITADELA SECTOR 49 FRACC 63 QUORUM  COME    CH-N1
# 77576  CITADELA SECTOR 49 FRACC 63 QUORUM  COME    CH-N1
# 77579  CITADELA SECTOR 49 FRACC 63 QUORUM  COME    CH-N1
# 77580  CITADELA SECTOR 49 FRACC 63 QUORUM  COME    CH-N1
# 77582  CITADELA SECTOR 49 FRACC 63 QUORUM  COME    CH-N1
# 77583  CITADELA SECTOR 49 FRACC 63 QUORUM  COME    CH-N1
# 77743  TABACALERAS YA RROYO EL CALORIENTO     S    CH-G2
# 77744  TABACALERAS YA RROYO EL CALORIENTO     S    CH-G2

# %%
typed_time_duplicates.count()
# Out:
# Year                   24
# tkt_code               24
# order_date             24
# order_code             24
# start_time             24
# truck_code             24
# ship_plant_code        24
# u_Volumen              24
# typed_time             24
# at_plant_time          24
# u_Cicle                24
# name                   24
# Nombre del proyecto    24
# ship_addr_line         24
# map_page               24
# dtype: int64

# %%
# Despite many trucks having the same start_time and at_plant_time theoretically, it is impossible that the same truck has the same start_time and at_plant_time
# Therefore, these are duplicates that should be removed, as they are likely to be errors in the data entry process.
remissions_df = remissions_df.drop(typed_time_duplicates.index)
print("Number of rows after dropping duplicates:", remissions_df.shape[0])
# Out:
# Number of rows after dropping duplicates: 340220

# %%
print(remissions_df.shape[0])
# Out:
# 340220

# %%
# Count unique values for each column
unique_counts = remissions_df.nunique()
print(unique_counts)
# Out:
# Year                        7
# tkt_code               325958
# order_date               1688
# order_code                778
# start_time              65153
# truck_code                150
# ship_plant_code             7
# u_Volumen                  32
# typed_time             336707
# at_plant_time          336629
# u_Cicle                   209
# name                     2022
# Nombre del proyecto     22890
# ship_addr_line          70947
# map_page                  952
# dtype: int64

# %% [markdown]
# Based on the initial unique values for each column:
# - There have been 778 orders in total
# - There have been 150 trucks
# - There have been 22890 different projects
# - There have been 2022 different clients (apparently)
# - There have been 70947 different addresses for delivery

# %%
remissions_df[remissions_df['tkt_code'].duplicated(keep=False)].sort_values('tkt_code', ascending=True).head(6)
#Looks like the tkt_codes can be repeated after years of orders.
# Out:
#         Year  tkt_code order_date  order_code          start_time  truck_code  \
# 1       2020  51013233 2020-02-04        1073 2020-02-04 07:00:00        6603
# 310446  2025  51013233 2025-08-02        1035 2025-08-02 07:00:00        9430
# 310448  2025  51013236 2025-08-02        1201 2025-08-02 07:00:00        7043
# 3       2020  51013236 2020-02-04        1005 2020-02-04 08:15:00        6598
# 310450  2025  51013239 2025-08-02        1090 2025-08-02 08:00:00        9430
# 5       2020  51013239 2020-02-04        1150 2020-02-04 09:00:00        6611
#
#        ship_plant_code  u_Volumen          typed_time       at_plant_time  \
# 1                  510        5.5 2020-02-04 06:45:22 2020-02-04 08:26:06
# 310446             510        2.0 2025-08-02 06:46:30 2025-08-02 07:46:17
# 310448             510        4.0 2025-08-02 06:54:06 2025-08-02 08:14:23
# 3                  510        3.0 2020-02-04 08:02:36 2020-02-04 09:47:43
# 310450             510        6.5 2025-08-02 07:46:56 2025-08-02 09:03:00
# 5                  510        6.0 2020-02-04 08:36:24 2020-02-04 09:30:24
#
#         u_Cicle                               name  \
# 1           101              ONE TIME OCTAVIO RIOS
# 310446       60  ONE TIME PROMOCIONES OCTAVIO RIOS
# 310448       80              JONATHAN MARQUEZ BACA
# 3           105           IVAN NOE SIMENTAL ORTEGA
# 310450       77     FERRETERIA MOLINA DE CHIHUAHUA
# 5            54     JULIO ARMANDO HINOJOS ENRIQUEZ
#
#                    Nombre del proyecto  \
# 1                   ARMENDARIZ ARMANDO
# 310446                MARGARITO ROMERO
# 310448                    OBRAS VARIAS
# 3                  COLECTOR SACRAMENTO
# 310450  FERRETERIA MOLINA DE CHIHUAHUA
# 5          FRAC CALZADA DEL BOSQUE AGH
#
#                                   ship_addr_line map_page
# 1       HACIENDAS HENEKENERAS 2679 GRACC HACIEND    CH-F1
# 310446        ING. CARRILLO  16344 COL TRAHUMARA    CHJ-3
# 310448          ARROYO NARAGUA #2225 LOS ARROYOS    CHD-5
# 3           ARROLLO MIMBRE Y VIALIDAD SACRAMENTO    CH-J9
# 310450      MONTE HIMALAYA 4341 QUINTAS CAROLINA    CHH-8
# 5       FRAC CALZADA DEL BOSQUE AGH     FRAC CAL    CH-H3

# %%
print(remissions_df['ship_plant_code'].unique())
# The new plant (717) was not used for the past version of this project
# Out:
# [510, 511, 512, 515, 710, 717, 514]
# Categories (7, int64): [510, 511, 512, 514, 515, 710, 717]

# %%
counts = remissions_df['ship_plant_code'].value_counts()
percentages = (counts / counts.sum()) * 100
print(counts, '\t', percentages.round(2)) # percentages
print("total:", counts.sum())

# Plant 717 has 2004 remissions. Despite those low numbers, we can keep it for two reasons:
# 1. It is a new plant that will be used and will affect the future of GCC.
# 2. Even if we cannot make a model for it just yet, we have to consider its location and presence in consumer behavior.
# Out:
# ship_plant_code
# 512    79487
# 510    68930
# 511    58374
# 515    49380
# 710    44728
# 514    37317
# 717     2004
# Name: count, dtype: int64 	 ship_plant_code
# 512    23.36
# 510    20.26
# 511    17.16
# 515    14.51
# 710    13.15
# 514    10.97
# 717     0.59
# Name: count, dtype: float64
# total: 340220
